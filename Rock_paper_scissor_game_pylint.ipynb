# %%
# %%writefile rps.py
# import random module 
import random 
  
# Print multiline instruction 
# performstring concatenation of string 
print("Winning Rules of the Rock paper scissor game as follows: \n"
                                +"Rock vs paper->paper wins \n"
                                + "Rock vs scissor->Rock wins \n"
                                +"paper vs scissor->scissor wins \n") 
  
while True: 
    print("Enter choice \n 1. Rock \n 2. paper \n 3. scissor \n") 
      
    # take the input from user 
    choice = int(input("User turn: ")) 
  
    # OR is the short-circuit operator 
    # if any one of the condition is true 
    # then it return True value 
      
    # looping until user enter invalid input 
    while choice > 3 or choice < 1: 
        choice = int(input("enter valid input: ")) 
          
  
    # initialize value of choice_name variable 
    # corresponding to the choice value 
    if choice == 1: 
        choice_name = 'Rock'
    elif choice == 2: 
        choice_name = 'paper'
    else: 
        choice_name = 'scissor'
          
    # print user choice  
    print("user choice is: " + choice_name) 
    print("\nNow its computer turn.......") 
  
    # Computer chooses randomly any number  
    # among 1 , 2 and 3. Using randint method 
    # of random module 
    comp_choice = random.randint(1, 3) 
      
    # looping until comp_choice value  
    # is equal to the choice value 
    while comp_choice == choice: 
        comp_choice = random.randint(1, 3) 
  
    # initialize value of comp_choice_name  
    # variable corresponding to the choice value 
    if comp_choice == 1: 
        comp_choice_name = 'Rock'
    elif comp_choice == 2: 
        comp_choice_name = 'paper'
    else: 
        comp_choice_name = 'scissor'
          
    print("Computer choice is: " + comp_choice_name) 
  
    print(choice_name + " V/s " + comp_choice_name) 
  
    # condition for winning 
    if((choice == 1 and comp_choice == 2) or
      (choice == 2 and comp_choice ==1 )): 
        print("paper wins => ", end = "") 
        result = "paper"
          
    elif((choice == 1 and comp_choice == 3) or
        (choice == 3 and comp_choice == 1)): 
        print("Rock wins =>", end = "") 
        result = "Rock"
    elif(choice == 3 and comp_choice == 1): 
        print("Rock wins =>", end = "")
    else: 
        print("scissor wins =>", end = "") 
        result = "scissor"
  
    # Printing either user or computer wins 
    if result == choice_name: 
        print("<== User wins ==>") 
    else: 
        print("<== Computer wins ==>") 
          
    print("Do you want to play again? (Y/N)") 
    ans = input() 
  
  
    # if user input n or N then condition is True 
    if ans == 'n' or ans == 'N': 
        break
      
# after coming out of the while loop 
# we print thanks for playing 
print("\nThanks for playing")
# Out:
# Writing rps.py

# %%
! Pylint rps.py
# Out:
# ************* Module rps
# rps.py:1:22: C0303: Trailing whitespace (trailing-whitespace)
# rps.py:2:13: C0303: Trailing whitespace (trailing-whitespace)
# rps.py:3:0: C0303: Trailing whitespace (trailing-whitespace)
# rps.py:4:29: C0303: Trailing whitespace (trailing-whitespace)
# rps.py:5:39: C0303: Trailing whitespace (trailing-whitespace)
# rps.py:7:0: C0330: Wrong continued indentation (remove 26 spaces).
#                                 +"Rock vs paper->paper wins \n"
#
#       |                         ^ (bad-continuation)
# rps.py:8:0: C0330: Wrong continued indentation (remove 26 spaces).
#                                 + "Rock vs scissor->Rock wins \n"
#
#       |                         ^ (bad-continuation)
# rps.py:9:0: C0330: Wrong continued indentation (remove 26 spaces).
#                                 +"paper vs scissor->scissor wins \n")
#
#       |                         ^ (bad-continuation)
# rps.py:9:69: C0303: Trailing whitespace (trailing-whitespace)
# rps.py:10:0: C0303: Trailing whitespace (trailing-whitespace)
# rps.py:11:11: C0303: Trailing whitespace (trailing-whitespace)
# rps.py:12:65: C0303: Trailing whitespace (trailing-whitespace)
# rps.py:13:0: C0303: Trailing whitespace (trailing-whitespace)
# rps.py:14:30: C0303: Trailing whitespace (trailing-whitespace)
# rps.py:15:38: C0303: Trailing whitespace (trailing-whitespace)
# rps.py:16:0: C0303: Trailing whitespace (trailing-whitespace)
# rps.py:17:38: C0303: Trailing whitespace (trailing-whitespace)
# rps.py:18:41: C0303: Trailing whitespace (trailing-whitespace)
# rps.py:19:31: C0303: Trailing whitespace (trailing-whitespace)
# rps.py:20:0: C0303: Trailing whitespace (trailing-whitespace)
# rps.py:21:44: C0303: Trailing whitespace (trailing-whitespace)
# rps.py:22:35: C0303: Trailing whitespace (trailing-whitespace)
# rps.py:23:50: C0303: Trailing whitespace (trailing-whitespace)
# rps.py:24:0: C0303: Trailing whitespace (trailing-whitespace)
# rps.py:25:0: C0303: Trailing whitespace (trailing-whitespace)
# rps.py:26:46: C0303: Trailing whitespace (trailing-whitespace)
# rps.py:27:39: C0303: Trailing whitespace (trailing-whitespace)
# rps.py:28:19: C0303: Trailing whitespace (trailing-whitespace)
# rps.py:30:21: C0303: Trailing whitespace (trailing-whitespace)
# rps.py:32:9: C0303: Trailing whitespace (trailing-whitespace)
# rps.py:34:0: C0303: Trailing whitespace (trailing-whitespace)
# rps.py:35:23: C0303: Trailing whitespace (trailing-whitespace)
# rps.py:36:43: C0303: Trailing whitespace (trailing-whitespace)
# rps.py:37:43: C0303: Trailing whitespace (trailing-whitespace)
# rps.py:38:0: C0303: Trailing whitespace (trailing-whitespace)
# rps.py:39:42: C0303: Trailing whitespace (trailing-whitespace)
# rps.py:40:45: C0303: Trailing whitespace (trailing-whitespace)
# rps.py:41:22: C0303: Trailing whitespace (trailing-whitespace)
# rps.py:42:38: C0303: Trailing whitespace (trailing-whitespace)
# rps.py:43:0: C0303: Trailing whitespace (trailing-whitespace)
# rps.py:44:37: C0303: Trailing whitespace (trailing-whitespace)
# rps.py:45:34: C0303: Trailing whitespace (trailing-whitespace)
# rps.py:46:32: C0303: Trailing whitespace (trailing-whitespace)
# rps.py:47:42: C0303: Trailing whitespace (trailing-whitespace)
# rps.py:48:0: C0303: Trailing whitespace (trailing-whitespace)
# rps.py:49:42: C0303: Trailing whitespace (trailing-whitespace)
# rps.py:50:48: C0303: Trailing whitespace (trailing-whitespace)
# rps.py:51:24: C0303: Trailing whitespace (trailing-whitespace)
# rps.py:53:26: C0303: Trailing whitespace (trailing-whitespace)
# rps.py:55:9: C0303: Trailing whitespace (trailing-whitespace)
# rps.py:57:0: C0303: Trailing whitespace (trailing-whitespace)
# rps.py:58:52: C0303: Trailing whitespace (trailing-whitespace)
# rps.py:59:0: C0303: Trailing whitespace (trailing-whitespace)
# rps.py:60:51: C0303: Trailing whitespace (trailing-whitespace)
# rps.py:61:0: C0303: Trailing whitespace (trailing-whitespace)
# rps.py:62:27: C0303: Trailing whitespace (trailing-whitespace)
# rps.py:64:0: C0330: Wrong continued indentation (add 1 space).
#       (choice == 2 and comp_choice ==1 )):
#
#       ^| (bad-continuation)
# rps.py:64:42: C0303: Trailing whitespace (trailing-whitespace)
# rps.py:64:35: C0326: Exactly one space required after comparison
#       (choice == 2 and comp_choice ==1 )):
#
#                                    ^^ (bad-whitespace)
# rps.py:64:39: C0326: No space allowed before bracket
#       (choice == 2 and comp_choice ==1 )):
#
#                                        ^ (bad-whitespace)
# rps.py:65:41: C0303: Trailing whitespace (trailing-whitespace)
# rps.py:65:36: C0326: No space allowed around keyword argument assignment
#         print("paper wins => ", end = "")
#
#                                     ^ (bad-whitespace)
# rps.py:67:0: C0303: Trailing whitespace (trailing-whitespace)
# rps.py:69:0: C0330: Wrong continued indentation (add 1 space).
#         (choice == 3 and comp_choice == 1)):
#
#         ^| (bad-continuation)
# rps.py:69:44: C0303: Trailing whitespace (trailing-whitespace)
# rps.py:70:39: C0303: Trailing whitespace (trailing-whitespace)
# rps.py:70:34: C0326: No space allowed around keyword argument assignment
#         print("Rock wins =>", end = "")
#
#                                   ^ (bad-whitespace)
# rps.py:72:43: C0303: Trailing whitespace (trailing-whitespace)
# rps.py:73:34: C0326: No space allowed around keyword argument assignment
#         print("Rock wins =>", end = "")
#
#                                   ^ (bad-whitespace)
# rps.py:74:9: C0303: Trailing whitespace (trailing-whitespace)
# rps.py:75:42: C0303: Trailing whitespace (trailing-whitespace)
# rps.py:75:37: C0326: No space allowed around keyword argument assignment
#         print("scissor wins =>", end = "")
#
#                                      ^ (bad-whitespace)
# rps.py:77:0: C0303: Trailing whitespace (trailing-whitespace)
# rps.py:78:43: C0303: Trailing whitespace (trailing-whitespace)
# rps.py:79:29: C0303: Trailing whitespace (trailing-whitespace)
# rps.py:80:34: C0303: Trailing whitespace (trailing-whitespace)
# rps.py:81:9: C0303: Trailing whitespace (trailing-whitespace)
# rps.py:82:38: C0303: Trailing whitespace (trailing-whitespace)
# rps.py:83:0: C0303: Trailing whitespace (trailing-whitespace)
# rps.py:84:45: C0303: Trailing whitespace (trailing-whitespace)
# rps.py:85:17: C0303: Trailing whitespace (trailing-whitespace)
# rps.py:86:0: C0303: Trailing whitespace (trailing-whitespace)
# rps.py:87:0: C0303: Trailing whitespace (trailing-whitespace)
# rps.py:88:49: C0303: Trailing whitespace (trailing-whitespace)
# rps.py:89:32: C0303: Trailing whitespace (trailing-whitespace)
# rps.py:91:0: C0303: Trailing whitespace (trailing-whitespace)
# rps.py:92:36: C0303: Trailing whitespace (trailing-whitespace)
# rps.py:93:29: C0303: Trailing whitespace (trailing-whitespace)
# rps.py:1:0: C0114: Missing module docstring (missing-module-docstring)
# rps.py:15:4: C0103: Constant name "choice" doesn't conform to UPPER_CASE naming style (invalid-name)
# rps.py:23:8: C0103: Constant name "choice" doesn't conform to UPPER_CASE naming style (invalid-name)
# rps.py:29:8: C0103: Constant name "choice_name" doesn't conform to UPPER_CASE naming style (invalid-name)
# rps.py:31:8: C0103: Constant name "choice_name" doesn't conform to UPPER_CASE naming style (invalid-name)
# rps.py:33:8: C0103: Constant name "choice_name" doesn't conform to UPPER_CASE naming style (invalid-name)
# rps.py:42:4: C0103: Constant name "comp_choice" doesn't conform to UPPER_CASE naming style (invalid-name)
# rps.py:47:8: C0103: Constant name "comp_choice" doesn't conform to UPPER_CASE naming style (invalid-name)
# rps.py:52:8: C0103: Constant name "comp_choice_name" doesn't conform to UPPER_CASE naming style (invalid-name)
# rps.py:54:8: C0103: Constant name "comp_choice_name" doesn't conform to UPPER_CASE naming style (invalid-name)
# rps.py:56:8: C0103: Constant name "comp_choice_name" doesn't conform to UPPER_CASE naming style (invalid-name)
# rps.py:66:8: C0103: Constant name "result" doesn't conform to UPPER_CASE naming style (invalid-name)
# rps.py:71:8: C0103: Constant name "result" doesn't conform to UPPER_CASE naming style (invalid-name)
# rps.py:76:8: C0103: Constant name "result" doesn't conform to UPPER_CASE naming style (invalid-name)
# rps.py:85:4: C0103: Constant name "ans" doesn't conform to UPPER_CASE naming style (invalid-name)
# rps.py:89:7: R1714: Consider merging these comparisons with "in" to "ans in ('n', 'N')" (consider-using-in)
#
# ----------------------------------------------------------------------
#
# Your code has been rated at -14.76/10 (previous run: -14.76/10, +0.00)
